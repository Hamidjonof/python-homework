# %%
import pandas as pd

df = pd.read_csv('task\\stackoverflow_qa.csv')

# 2014 yilgacha yaratilgan barcha savollar
df_2014dan_oldin = df[pd.to_datetime(df['yaratilishdate']) < '2014-01-01']

# 50 dan ortiq ball bilan barcha savollar
df_50dan_ortiq = df[df['hisob'] > 50]

# 50 dan 100 gacha ball bilan barcha savollar
df_50_100 = df[(df['hisob'] > 50) & (df['hisob'] <= 100)]

# Skott Boston javob bergan barcha savollar
df_skott = df[df['_nomi.ans_rep'] == 'Skott Boston']

# Quyidagi 5 foydalanuvchi javob bergan savollar
users = ['Skott Boston', 'unutbu', 'unutbu', 'Martijn Pieters', 'DSM']
df_5_user = df[df['_nomi.ans_rep'].isin(users)]

# 2014 yil mart va oktyabr orasida, Unutbu tomonidan javob berilgan va 5 dan kam ball
df_unutbu = df[
    (pd.to_datetime(df['yaratilishdate']) >= '2014-03-01') &
    (pd.to_datetime(df['yaratilishdate']) <= '2014-10-31') &
    (df['_nomi.ans_rep'] == 'unutbu') &
    (df['hisob'] < 5)
]

# 5 dan 10 gacha ball yoki ko'rish soni 10 000 dan ortiq
df_5_10_or_views = df[
    ((df['hisob'] >= 5) & (df['hisob'] <= 10)) |
    (df["ko'rish soni"] > 10000)
]

# Skott Boston javob bermagan barcha savollar
df_not_skott = df[df['_nomi.ans_rep'] != 'Skott Boston']
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 3
#       1 import pandas as pd
# ----> 3 df = pd.read_csv('task\\stackoverflow_qa.csv')
#       5 # 2014 yilgacha yaratilgan barcha savollar
#       6 df_2014dan_oldin = df[pd.to_datetime(df['yaratilishdate']) < '2014-01-01']
#
# ...

# %%
import pandas as pd

df = pd.read_csv('task\\stackoverflow_qa.csv')

# 2014 yilgacha yaratilgan barcha savollar
df_2014dan_oldin = df[pd.to_datetime(df['yaratilishdate']) < '2014-01-01']

# 50 dan ortiq ball bilan barcha savollar
df_50dan_ortiq = df[df['hisob'] > 50]

# 50 dan 100 gacha ball bilan barcha savollar
df_50_100 = df[(df['hisob'] > 50) & (df['hisob'] <= 100)]

# Skott Boston javob bergan barcha savollar
df_skott = df[df['_nomi.ans_rep'] == 'Skott Boston']

# Quyidagi 5 foydalanuvchi javob bergan savollar
users = ['Skott Boston', 'unutbu', 'unutbu', 'Martijn Pieters', 'DSM']
df_5_user = df[df['_nomi.ans_rep'].isin(users)]

# 2014 yil mart va oktyabr orasida, Unutbu tomonidan javob berilgan va 5 dan kam ball
df_unutbu = df[
    (pd.to_datetime(df['yaratilishdate']) >= '2014-03-01') &
    (pd.to_datetime(df['yaratilishdate']) <= '2014-10-31') &
    (df['_nomi.ans_rep'] == 'unutbu') &
    (df['hisob'] < 5)
]

# 5 dan 10 gacha ball yoki ko'rish soni 10 000 dan ortiq
df_5_10_or_views = df[
    ((df['hisob'] >= 5) & (df['hisob'] <= 10)) |
    (df["ko'rish soni"] > 10000)
]

# Skott Boston javob bermagan barcha savollar
df_not_skott = df[df['_nomi.ans_rep'] != 'Skott Boston']
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 3
#       1 import pandas as pd
# ----> 3 df = pd.read_csv('task\\stackoverflow_qa.csv')
#       5 # 2014 yilgacha yaratilgan barcha savollar
#       6 df_2014dan_oldin = df[pd.to_datetime(df['yaratilishdate']) < '2014-01-01']
#
# ...

# %%
titanic_df = pd.read_csv("task\\titanic.csv")

# Sinfda ayol yo'lovchi (1-sinf) va yoshi 20-30 oralig'ida
female_class1_20_30 = titanic_df[
    (titanic_df['Jinsiy aloqa'] == 'ayol') &
    (titanic_df['Kompyuter'] == 1) &
    (titanic_df['Yoshi'].between(20, 30))
]

# $100 dan ortiq pul to'lagan yo'lovchilar
fare_over_100 = titanic_df[titanic_df['Yo‘l haqi'] > 100]

# Omon qolgan va yolg'iz yo'lovchilar (SibSp == 0 va Parch == 0)
alone_survivors = titanic_df[
    (titanic_df['Omon qolgan'] == 1) &
    (titanic_df['Sibspaper size'] == 0) &
    (titanic_df['Parch'] == 0)
]

# 'C' dan kirgan va $50 dan ortiq to'laganlar
embarked_c_and_fare = titanic_df[
    (titanic_df['Boshlandi'] == 'C') &
    (titanic_df['Yo‘l haqi'] > 50)
]

# Ikkala: SibSp > 0 va Parch > 0
both_family_abroad = titanic_df[
    (titanic_df['Sibspaper size'] > 0) &
    (titanic_df['Parch'] > 0)
]

# 15 yoshdan kichik va omon qolmaganlar
under15_not_survived = titanic_df[
    (titanic_df['Yoshi'] <= 15) &
    (titanic_df['Omon qolgan'] == 0)
]

# Kabinasi bor va $200 dan ortiq to'laganlar
cabin_and_fare = titanic_df[
    titanic_df['Idishni'].notna() &
    (titanic_df['Yo‘l haqi'] > 200)
]

# Faqat toq id-lar
odd_passenger_ids = titanic_df[titanic_df['Yo\'lovchilar'] % 2 == 1]

# Unikal chipta raqamlar
unique_ticket = titanic_df[
    titanic_df.duplicated('Chipta', keep=False) == False
]

# Ismida 'Miss' bor va 1-sinfda bo'lgan ayollar
miss_class1 = titanic_df[
    (titanic_df['Nomi'].str.contains('Miss')) &
    (titanic_df['Kompyuter'] == 1) &
    (titanic_df['Jinsiy aloqa'] == 'ayol')
]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 titanic_df = pd.read_csv("task\\titanic.csv")
#       3 # Sinfda ayol yo'lovchi (1-sinf) va yoshi 20-30 oralig'ida
#       4 female_class1_20_30 = titanic_df[
#       5     (titanic_df['Jinsiy aloqa'] == 'ayol') &
#       6     (titanic_df['Kompyuter'] == 1) &
#       7     (titanic_df['Yoshi'].between(20, 30))
#       8 ]
#
# ...
